# %% [markdown]
# # Task 1
# - Creating a csv file
# -Create a csv file with fist attribute as x-coordinate and second attributes as y coordinate with x and y values ranging between [0; 10] and the number of
# rows can between [10 - 20] of your choice.

# %%
#Method 1

import csv # Importing csv module

# writing to csv file 
with open('inkprog.csv', 'w', newline='') as file:
    writer = csv.writer(file)  # creating a csv writer object 
    field = ["x", "y"] # field names
    
    # data rows of csv file 
    writer.writerow(field) # writing the fields 
    writer.writerow(["0", "1"])
    writer.writerow(["2", "3"]) # writing the data rows 
    writer.writerow(["4", "5"])
    writer.writerow(["5.5", "6"])
    writer.writerow(["6.9", "7.2"])
    writer.writerow(["8", "8.5"])
    writer.writerow(["9", "1"])
    writer.writerow(["10", "2.5"])
    writer.writerow(["9.7", "7"])
    writer.writerow(["5", "6.7"])
    writer.writerow(["6", "7"])
    writer.writerow(["8", "8.5"])

# %% [markdown]
# ### Method2 --> Using csv.writer class

# %%
import csv 
    
fields = ['x', 'y']  # field names 
# data rows of csv file 
rows = [['2','9'],
        ['1','7.1'], 
        ['0', '6.3'], 
        ['8','9.5'], 
        ['3','6'], 
        ['10', '8'],
        ['3', '9'],
        ['0.5', '7'],
        ['5', '8'],
        ['4', '6']] 

   
with open("inkprog_new.csv", 'w') as csvfile:  # writing to csv file 
    # creating a csv writer object 
    csvwriter = csv.writer(csvfile) 
    # writing the fields 
    csvwriter.writerow(fields) 
    # writing the data rows 
    csvwriter.writerows(rows)

# %% [markdown]
# ### Method 3 --> Using csv.DictWriter class

# %%
import csv # importing the csv module 
    
# my data rows as dictionary objects 
mydict =[{'x': '0', 'y': '9.1'}, 
         {'x': '2', 'y': '1'}, 
         {'x': '4', 'y': '3'}, 
         {'x': '7', 'y': '5'}, 
         {'x': '8', 'y': '8'}, 
         {'x': '6', 'y': '9'},
         {'x': '5', 'y': '9.1'}, 
         {'x': '6', 'y': '4'}, 
         {'x': '7', 'y': '3'}, 
         {'x': '9', 'y': '7'}, 
         {'x': '10', 'y': '8'}, 
         {'x': '7.5', 'y': '5.5'}] 
    
# field names 
fields = ['x', 'y'] 
    
# writing to csv file 
with open("testing.csv", 'w') as csvfile: 
    # creating a csv dict writer object 
    writer = csv.DictWriter(csvfile, fieldnames = fields) 
        
    # writing headers (field names) 
    writer.writeheader() 
        
    # writing data rows 
    writer.writerows(mydict)

# %% [markdown]
# # Task 2
# - Using the created csv file find the best line that fits the data (linear regression) using. python. Write the equation of the line its slope and y intercept end of
# the code.

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# Provided data
X = np.array([0, 2, 4, 5.5, 6.9, 8, 9, 10, 9.7, 5, 6, 8])
y = np.array([1, 3, 5, 6, 7.2, 8.5, 1, 2.5, 7, 6.7, 7, 8.5])

# Reshape the data
X = X.reshape(-1, 1)
y = y.reshape(-1, 1)

# Perform linear regression
reg = LinearRegression().fit(X, y)

# Get slope and y-intercept
slope = reg.coef_[0][0]
intercept = reg.intercept_[0]

# Print results
print("Equation of the line: y =", slope, "* x +", intercept)
print("Slope:", slope)
print("Y-intercept:", intercept)
# Out:
# Equation of the line: y = 0.29300888558905946 * x + 3.4740034648208917
# Slope: 0.29300888558905946
# Y-intercept: 3.4740034648208917

# %% [markdown]
# ### For another  data

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# Provided data
X = np.array([2, 1, 0, 8, 3, 10, 3, 0.5, 5, 4])
y = np.array([9, 7.1,6.3,9.5,6,8,9,7,8,6])

# Reshape the data
X = X.reshape(-1, 1)
y = y.reshape(-1, 1)

# Perform linear regression
reg = LinearRegression().fit(X, y)

# Get slope and y-intercept
slope = reg.coef_[0][0]
intercept = reg.intercept_[0]

# Print results
print("Equation of the line: y =", slope, "* x +", intercept)
print("Slope:", slope)
print("Y-intercept:", intercept)
# Out:
# Equation of the line: y = 0.17432254669823735 * x + 6.953722704551434
# Slope: 0.17432254669823735
# Y-intercept: 6.953722704551434

# %% [markdown]
# # Task 3
# - Using manim library create a video visulization where an x , y axis is created and then plot the points in the csv file you created and draw then the line we
# got after applying linear regression on the csv file data points and write the equation of the line using latex. To make your output unique add a title card
# with Name: linear regression and your name below it.

# %% [markdown]
# ## Plotting the data using matplotlib

# %% [markdown]
# ### Plot 1 --> plotting the data and joining them

# %%
import pandas as pd
data = pd.read_csv("inkprog.csv")

x = data['x']
y = data['y']

import matplotlib.pyplot as plt
fig = plt.figure()
my_axes = fig.add_axes([0.1,0.1,1.6,1.6])
my_axes.plot(x,'r',lw=3,label = "x")
my_axes.plot(y,'b',lw=3,label="y")
my_axes.set_xlabel ("X data ")
my_axes.set_ylabel ("Y data") 
my_axes.set_title("X and Y data")
my_axes.legend()

# %% [markdown]
# ### Plot 2 --> simply ploting the data points

# %%
x = data['x'].to_numpy().reshape(-1, 1)
y = data['y'].to_numpy().reshape(-1, 1)

plt.scatter(x, y, c='g', label='x vs. y')
plt.legend()
plt.show()

# %% [markdown]
# ### Plot 3 --> using interactive plot and linear regression to plot the data

# %%
# Enable interactive plot
# %matplotlib notebook
# %matplotlib notebook

import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from sklearn.linear_model import LinearRegression


x_data = []
y_data = []

fig, ax = plt.subplots()     
ax.set_xlim(0, 11)
ax.set_ylim(0, 10)
# Plotting 
scatter, = ax.plot([], [], 'go', label='x vs. y')
line, = ax.plot([], [], 'r', label='Linear Regression')
ax.legend()

reg = LinearRegression()

def animate(frame_num):
    # Adding data
    x_data.append(x[frame_num])
    y_data.append(y[frame_num])
    # Convert data to numpy array
    x_train = np.array(x_data).reshape(-1, 1)
    y_train = np.array(y_data).reshape(-1, 1)
    # Fit values to a linear regression
    reg.fit(x_train, y_train)

    # update data for scatter plot
    scatter.set_data((x_data, y_data))
    # Predict value and update data for line plot
    line.set_data((list(range(250)), reg.predict(np.array([entry for entry in range(250)]).reshape(-1, 1))))

anim = FuncAnimation(fig, animate, frames=len(x), interval=20)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.animation import FuncAnimation
from sklearn.linear_model import LinearRegression

df = pd.read_csv('inkprog.csv')
x = df['x'].to_numpy()
y = df['y'].to_numpy()

x_train = []
y_train = []
x_test = np.arange(x.min(), x.max() + 1).reshape(-1, 1)

fig, ax = plt.subplots(figsize=(8, 4))
ax.set_xlim(x.min(), x.max())
ax.set_ylim(y.min(), y.max())
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.grid()

scatter, = ax.plot([], [], 'go')
line, = ax.plot([], [], 'r')

lr = LinearRegression()


def animate(n):
    x_train.append([x[n]])
    y_train.append([y[n]])

    lr.fit(x_train, y_train)
    y_test = lr.predict(x_test)

    scatter.set_data(x_train, y_train)
    line.set_data(x_test, y_test)


anim = FuncAnimation(fig, animate, frames=x.size, interval=200, repeat=False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">

# %% [markdown]
# # Using manim library

# %% [markdown]
# ### Creating axis

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from manim import *  

class MyBeautifulGraph(Scene):
    def construct(self):
        axes = Axes()
        self.add(axes)

# %% [markdown]
# ### Creating line

# %%
class MyBeautifulGraph(Scene):
    def construct(self):
        axes = Axes()
        x = [0, 2, 4, 5.5, 6.9, 8, 9, 10, 9.7, 5, 6, 8]
        y = [1, 3, 5, 6, 7.2, 8.5, 1, 2.5, 7, 6.7, 7, 8.5]
        line = axes.plot_line_graph(x, y, add_vertex_dots=False)
        self.add(axes, line)

# %% [markdown]
# ### Creating shaded part

# %%
import numpy as np

class MyBeautifulGraph(Scene):
    def construct(self):
        axes = Axes()
        x = [0, 2, 4, 5.5, 6.9, 8, 9, 10, 9.7, 5, 6, 8]
        y = [1, 3, 5, 6, 7.2, 8.5, 1, 2.5, 7, 6.7, 7, 8.5]
        low_q = [-1, 0, 1, 1, 2]
        high_q = [2, 3, 5, 4, 4]
        line = axes.plot_line_graph(x, y, add_vertex_dots=False)
        # the following two lines won't be added to the scene!
        low_q_curve = axes.plot_line_graph(x, low_q)
        high_q_curve = axes.plot_line_graph(x, high_q)
        # get the points from the lines
        low_points = low_q_curve["line_graph"].points
        high_points = high_q_curve["line_graph"].points
        # and create a polygon, using those points
        points = np.concatenate((low_points, np.flip(high_points, 0)))
        area = Polygon(*points, fill_opacity=0.2)
        self.add(axes, line, area)

# %% [markdown]
# ### Title

# %%
title = Text("Linear regression by mohammed ali")
title.next_to(axes, UP)

# axis label
x_label = axes.get_x_axis_label("x\\text{ label}")
y_label = axes.get_y_axis_label("y\\text{ label}")

# %% [markdown]
# ### Try two for manim part

# %%
import numpy as np
from manim import *

def build_plot(axes, x, y, low_q, high_q, color):
    line = axes.plot_line_graph(x, y, add_vertex_dots=False, line_color=color)
    low_q_curve = axes.plot_line_graph(x, low_q)
    high_q_curve = axes.plot_line_graph(x, high_q)
    low_points = low_q_curve["line_graph"].points
    high_points = high_q_curve["line_graph"].points
    points = np.concatenate((low_points, np.flip(high_points, 0)))
    area = Polygon(*points, fill_opacity=0.2, stroke_width=0.0, color=color)
    return VDict({"line": line, "area": area})

class Linear_regression(Scene):
    def construct(self):
        x_min, x_max, x_step = 0, 4, 1
        y_min, y_max, y_step = -1, 5, 1
        axes = Axes(
            x_range=[x_min, x_max + x_step, x_step],
            y_range=[y_min, y_max + y_step, y_step],
            x_axis_config={
                "numbers_to_include": range(x_min, x_max + x_step, x_step),
            },
            y_axis_config={
                "numbers_to_include": range(y_min, y_max + y_step, y_step),
            },
        )
        x_label = axes.get_x_axis_label("x\\text{ label}")
        y_label = axes.get_y_axis_label("y\\text{ label}")
        x = [0, 1, 2, 3, 4]
        y = [1, 2, 4, 2, 3]
        low_q = [-1, 0, 1, 1, 2]
        high_q = [2, 3, 5, 4, 4]
        plot = build_plot(axes, x, y, low_q, high_q, color=RED)
        title = Text("My beautiful graph")
        title.next_to(axes, UP)
        self.play(Create(axes), Write(x_label), Write(y_label), Write(title))
        self.play(Create(plot["line"]))
        self.play(FadeIn(plot["area"]))
        self.wait()
